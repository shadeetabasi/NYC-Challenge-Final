# %%
import pandas as pd
housing = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/re_data_clean.csv")
walk = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/walkscore_data_clean.csv")
trees = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/tree_data_clean.csv")
stations = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/stations_data_clean.csv")
brownfields = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/brownfields_data_clean.csv")
crime = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/crime_data_clean.csv")
elem = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/final_elementary.csv")
middle = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/final_middle.csv")
high = pd.read_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/final_high.csv")

# %% [markdown]
# ### Walkability

# %%
walk = walk[['zipcode', 'walkable_false', 'walkable_true']]

walk = walk.groupby(by=["zipcode"]).sum()

walk.head()
# Out:
#          walkable_false  walkable_true
# zipcode
# 10001                 0             18
# 10002                 0             35
# 10003                 0             60
# 10004                 0              4
# 10005                 0             14

# %%
trees.columns
# Out:
# Index(['index', 'boro_ct', 'borocode', 'borough', 'health', 'latitude',
#        'longitude', 'nta', 'neighborhood', 'species', 'status', 'tree_id',
#        'year_planted', 'zipcode', 'status_tier', 'status_alive', 'status_dead',
#        'status_stump', 'health_level', 'health_level_dead',
#        'health_level_fair', 'health_level_good', 'health_level_poor'],
#       dtype='object')

# %% [markdown]
# ### Trees

# %%
trees = trees[['zipcode','health_level_dead',
       'health_level_fair', 'health_level_good', 'health_level_poor']] 

trees = trees.groupby(by=["zipcode"]).sum()

trees.head()
# Out:
#          health_level_dead  health_level_fair  health_level_good  \
# zipcode
# 83                   3.000             39.000            885.000
# 10001               61.000            100.000            719.000
# 10002              107.000            387.000           1656.000
# 10003               82.000            361.000           1480.000
# 10004                1.000             17.000             97.000
#
#          health_level_poor
# zipcode
# 83                   8.000
# 10001               31.000
# 10002              115.000
# 10003              102.000
# 10004                3.000

# %%
stations.columns
# Out:
# Index(['index', 'ada_access', 'borough', 'lat_field', 'lon_field', 'line',
#        'station_id', 'station_name', 'ada_level', 'ada_access_no',
#        'ada_access_yes', 'ada_access_partial', 'location', 'zipcode'],
#       dtype='object')

# %% [markdown]
# ### Stations

# %%
stations = stations[['zipcode','ada_access_no',
       'ada_access_yes', 'ada_access_partial']]


stations = stations.groupby(by=["zipcode"]).sum()

stations.head()
# Out:
#          ada_access_no  ada_access_yes  ada_access_partial
# zipcode
# 10000                0               1                   0
# 10001                4               3                   0
# 10002                6               1                   0
# 10003                8               3                   0
# 10004                2               1                   0

# %% [markdown]
# ### Brownfields

# %%
brownfields = brownfields[['zipcode','type_is_active_cleanup_mild_threat',
       'type_is_active_significant_threat', 'type_is_completed_clean',
       'type_is_maintain_continued_threat', 'type_is_potential_threat']]


brownfields = brownfields.groupby(by=["zipcode"]).sum()

brownfields.head()
# Out:
#          type_is_active_cleanup_mild_threat  \
# zipcode
# 10001                                     3
# 10002                                     1
# 10004                                     1
# 10005                                     1
# 10007                                     0
#
#          type_is_active_significant_threat  type_is_completed_clean  \
# zipcode
# 10001                                    0                        7
# 10002                                    0                        0
# 10004                                    0                        2
# 10005                                    0                        0
# 10007                                    0                        1
#
#          type_is_maintain_continued_threat  type_is_potential_threat
# zipcode
# 10001                                    0                         1
# 10002                                    0                         0
# ...

# %% [markdown]
# ### Crime

# %%
crime = crime[['zipcode', 'type_is_felony', 'type_is_violation', 'type_is_misdemeanor', 'danger_level_is_high', 'danger_level_is_low']]


crime = crime.groupby(by=["zipcode"]).sum()


crime.head()
# Out:
#          type_is_felony  type_is_violation  type_is_misdemeanor  \
# zipcode
# 10001               308                166                  469
# 10002               614                265                 1084
# 10003               624                159                  947
# 10009               300                153                  483
# 10010               406                211                  685
#
#          danger_level_is_high  danger_level_is_low
# zipcode
# 10001                      77                  866
# 10002                     221                 1742
# 10003                     239                 1491
# 10009                      86                  850
# 10010                     189                 1113

# %%
elem.columns
# Out:
# Index(['Unnamed: 0', 'ranking', 'school_name', 'school_type', 'address',
#        'city', 'zipcode', 'county', 'district', 'is_charter', 'is_magnet',
#        'is_title_i', 'total_students', 'full_time_teachers',
#        'student_teacher_ratio', 'free_lunch_recipient', 'white', 'black',
#        'hispanic', 'asian', 'total_expenditure_per_pupil', 'ranking_quartile',
#        'type_is_Top 25th Percentile', 'type_is_50th Percentile',
#        'type_is_75th Percentile', 'type_is_Bottom 25th Percentile',
#        'lunch_eligibity_high', 'lunch_eligibity_high_False',
#        'lunch_eligibity_high_True'],
#       dtype='object')

# %%
elem = elem[['zipcode', 'lunch_eligibity_high_False','lunch_eligibity_high_True', 
             'type_is_Top 25th Percentile', 'type_is_50th Percentile',
             'type_is_75th Percentile', 'type_is_Bottom 25th Percentile']]


elem = elem.groupby(by=["zipcode"]).sum()


elem.head()
# Out:
#          lunch_eligibity_high_False  lunch_eligibity_high_True  \
# zipcode
# 10001                             1                          0
# 10002                             7                          7
# 10003                             3                          1
# 10007                             1                          0
# 10009                             4                          4
#
#          type_is_Top 25th Percentile  type_is_50th Percentile  \
# zipcode
# 10001                              1                        0
# 10002                              6                        2
# 10003                              3                        1
# 10007                              1                        0
# 10009                              1                        2
#
#          type_is_75th Percentile  type_is_Bottom 25th Percentile
# zipcode
# 10001                          0                               0
# ...

# %%
middle = middle[['zipcode', 'lunch_eligibity_high_False','lunch_eligibity_high_True', 
             'type_is_Top 25th Percentile', 'type_is_50th Percentile',
             'type_is_75th Percentile', 'type_is_Bottom 25th Percentile']]


middle = middle.groupby(by=["zipcode"]).sum()


middle.head()
# Out:
#          lunch_eligibity_high_False  lunch_eligibity_high_True  \
# zipcode
# 10002                             4                          5
# 10003                             5                          0
# 10004                             2                          0
# 10009                             2                          1
# 10010                             3                          0
#
#          type_is_Top 25th Percentile  type_is_50th Percentile  \
# zipcode
# 10002                              1                        3
# 10003                              3                        2
# 10004                              0                        1
# 10009                              0                        2
# 10010                              0                        3
#
#          type_is_75th Percentile  type_is_Bottom 25th Percentile
# zipcode
# 10002                          2                               3
# ...

# %%
high = high[['zipcode', 'lunch_eligibity_high_False','lunch_eligibity_high_True', 
             'type_is_Top 25th Percentile', 'type_is_50th Percentile',
             'type_is_75th Percentile', 'type_is_Bottom 25th Percentile']]


high = high.groupby(by=["zipcode"]).sum()


high.head()
# Out:
#          lunch_eligibity_high_False  lunch_eligibity_high_True  \
# zipcode
# 10002                             2                         11
# 10003                             3                          5
# 10004                             2                          3
# 10006                             0                          2
# 10010                             1                          2
#
#          type_is_Top 25th Percentile  type_is_50th Percentile  \
# zipcode
# 10002                              3                        1
# 10003                              1                        0
# 10004                              1                        0
# 10006                              0                        0
# 10010                              2                        0
#
#          type_is_75th Percentile  type_is_Bottom 25th Percentile
# zipcode
# 10002                          3                               6
# ...

# %%
frames = [walk, trees, stations, brownfields, crime, elem, middle, high]

nan_value = 0

result = pd.concat(frames, join='outer', axis=1).fillna(nan_value)
result.to_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/merged.csv")
result
# Out:
#          walkable_false  walkable_true  health_level_dead  health_level_fair  \
# zipcode
# 83                0.000          0.000              3.000             39.000
# 10000             0.000          0.000              0.000              0.000
# 10001             0.000         18.000             61.000            100.000
# 10002             0.000         35.000            107.000            387.000
# 10003             0.000         60.000             82.000            361.000
# ...                 ...            ...                ...                ...
# 11694           206.000          0.000            396.000            833.000
# 11697            82.000          0.000              6.000              8.000
# 12201             0.000          0.000              0.000              0.000
# 12692             0.000          0.000              0.000              0.000
# 21249             0.000          0.000              0.000              0.000
#
# ...

# %%
dfinal = housing.merge(result, on="zipcode", how = 'left')
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

dfinal = pd.DataFrame(dfinal).fillna(nan_value)

dfinal.to_csv("C:/Users/bxprd/Data Analytics Bootcamp/Git_Repos/NYC-Challenge-Final/python_files/output/merged_re.csv")

# del dfinal['listed_price']

dfinal
# Out:
#        index                         address       neighborhood    borough  \
# 0          0          219 w 14th st, unit 2f            chelsea  manhattan
# 1          1          315 w 70th st, unit 6a    upper west side  manhattan
# 2          2         306 w 100th st, unit 56    upper west side  manhattan
# 3          3             38 w 9th st, unit 1  greenwich village  manhattan
# 4          4            48 w 86th st, unit 2    upper west side  manhattan
# ...      ...                             ...                ...        ...
# 37223  37223  2906 brighton 12th st, unit 6f     brighton beach   brooklyn
# 37224  37224                   272 corbin pl     brighton beach   brooklyn
# 37225  37225            2831 brighton 4th st     brighton beach   brooklyn
# 37226  37226           2743 brighton 7th st.     brighton beach   brooklyn
# 37227  37227        105 oceana dr e, unit 5h     brighton beach   brooklyn
#
#        bed  bath  days_on_market compass_property_type  \
# ...

# %%
# Build the correlation matrix
import matplotlib.pyplot as plt
import seaborn as sns

matrix = dfinal.corr()
f, ax = plt.subplots(figsize=(30, 30))
sns.heatmap(matrix, vmax=0.9, square=True)
# Out:
# <AxesSubplot:>

# %%
interesting_variables = matrix['sold_price'].sort_values(ascending=False)
# Filter out the target variables (SalePrice) and variables with a low correlation score (v such that -0.6 <= v <= 0.6)
interesting_variables = interesting_variables[abs(interesting_variables) >= 0.4]
interesting_variables = interesting_variables[interesting_variables.index != 'sold_price']
interesting_variables
# Out:
# listed_price   0.812
# bath           0.422
# Name: sold_price, dtype: float64

# %%
#import libraries and dependencies
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %%
X = dfinal[['zipcode', 'sold_price','bed', 'bath', 'days_on_market', 'dom_tier', 'dom_lowerbound', 'dom_iqr', 'dom_upperbound','dom_extended', 
            'dom_outlier', 'walkable_false', 'walkable_true', 'health_level_dead', 'health_level_fair', 'health_level_good',
            'health_level_poor', 'ada_access_no', 'ada_access_yes', 'ada_access_partial', 
            'type_is_active_cleanup_mild_threat','type_is_active_significant_threat','type_is_completed_clean',
            'type_is_maintain_continued_threat', 'type_is_potential_threat', 'type_is_felony', 'type_is_violation', 
            'type_is_misdemeanor', 'danger_level_is_high', 'danger_level_is_low', 'lunch_eligibity_high_False', 
            'lunch_eligibity_high_True', 'type_is_Top 25th Percentile', 'type_is_50th Percentile', 'type_is_75th Percentile',
            'type_is_Bottom 25th Percentile', 'lunch_eligibity_high_False', 'lunch_eligibity_high_True', 
            'type_is_Top 25th Percentile', 'type_is_50th Percentile', 'type_is_75th Percentile', 
            'type_is_Bottom 25th Percentile', 'lunch_eligibity_high_False', 'lunch_eligibity_high_True', 
            'type_is_Top 25th Percentile', 'type_is_50th Percentile', 'type_is_75th Percentile', 
            'type_is_Bottom 25th Percentile' ]]

X.astype(int)
# Out:
#        zipcode  sold_price  bed  bath  days_on_market  dom_tier  \
# 0        10011     1646000    1     2              75         1
# 1        10023      799000    1     1              60         1
# 2        10025      670000    1     1             122         2
# 3        10011     2175000    2     3              72         1
# 4        10024     2333000    2     2             134         2
# ...        ...         ...  ...   ...             ...       ...
# 37223    11235      230000    1     1             105         1
# 37224    11235     2050000    7     5             105         1
# 37225    11235      800000    8     1             105         1
# 37226    11235      940000    8     4             105         1
# 37227    11235      850000    2     2              32         0
#
#        dom_lowerbound  dom_iqr  dom_upperbound  dom_extended  dom_outlier  \
# 0                   0        1               0             0            0
# ...

# %%
y = dfinal[['compass_property_type']]
y.dtypes
# Out:
# compass_property_type    object
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42, max_features="log2", min_samples_split=3, min_samples_leaf=2)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# <ipython-input-144-4edcdd1097bd>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf = rf.fit(X_train, y_train)
# 0.8711722359514344

# %%
sorted(zip(rf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.22702377089674156, 'sold_price'),
#  (0.17098407009058042, 'bed'),
#  (0.0862784132406331, 'bath'),
#  (0.057626756238041095, 'days_on_market'),
#  (0.02436927582821928, 'zipcode'),
#  (0.021330110029023165, 'health_level_dead'),
#  (0.018719372729952076, 'health_level_good'),
#  (0.017435724515180634, 'type_is_active_cleanup_mild_threat'),
#  (0.017299513358023193, 'walkable_true'),
#  (0.016796593791125122, 'type_is_misdemeanor'),
#  (0.014071831894767479, 'health_level_poor'),
#  (0.013494463547956092, 'type_is_completed_clean'),
#  (0.012190500992715368, 'dom_tier'),
#  (0.01185783030881352, 'dom_iqr'),
#  (0.011515780400904048, 'health_level_fair'),
#  (0.011058285225956812, 'danger_level_is_low'),
#  (0.0109943090717523, 'danger_level_is_high'),
#  (0.0105512969263687, 'type_is_felony'),
#  (0.010069399519238631, 'type_is_violation'),
#  (0.008846813107281101, 'walkable_false'),
#  (0.0072284919665353865, 'lunch_eligibity_high_False'),
# ...

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix,accuracy_score
confusion_matrix(y_test, y_pred)
# Out:
# array([[1787,  204,    2,   89],
#        [ 227, 1360,    1,  250],
#        [  15,    5,   44,  202],
#        [  63,  131,   10, 4917]], dtype=int64)

# %%
plot_confusion_matrix(rf,X_test,y_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        co-op       0.85      0.86      0.86      2082
#        condo       0.80      0.74      0.77      1838
#        house       0.77      0.17      0.27       266
#    townhouse       0.90      0.96      0.93      5121
#
#     accuracy                           0.87      9307
#    macro avg       0.83      0.68      0.71      9307
# weighted avg       0.87      0.87      0.86      9307

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from numpy import mean
from numpy import std

X1 = dfinal[['zipcode','bed', 'bath', 'days_on_market', 'dom_tier', 'dom_lowerbound', 'dom_iqr', 'dom_upperbound','dom_extended', 
            'dom_outlier', 'walkable_false', 'walkable_true', 'health_level_dead', 'health_level_fair', 'health_level_good',
            'health_level_poor', 'ada_access_no', 'ada_access_yes', 'ada_access_partial', 
            'type_is_active_cleanup_mild_threat','type_is_active_significant_threat','type_is_completed_clean',
            'type_is_maintain_continued_threat', 'type_is_potential_threat', 'type_is_felony', 'type_is_violation', 
            'type_is_misdemeanor', 'danger_level_is_high', 'danger_level_is_low', 'lunch_eligibity_high_False_elem', 
            'lunch_eligibity_high_True_elem', 'type_is_Top 25th Percentile_elem', 'type_is_50th Percentile_elem', 
            'type_is_75th Percentile_elem','type_is_Bottom 25th Percentile_elem', 'lunch_eligibity_high_False_middle', 
            'lunch_eligibity_high_True_middle','type_is_Top 25th Percentile_middle', 'type_is_50th Percentile_middle', 
            'type_is_75th Percentile_middle','type_is_Bottom 25th Percentile_middle', 'lunch_eligibity_high_False_high', 
            'lunch_eligibity_high_True_high','type_is_Top 25th Percentile_high', 'type_is_50th Percentile_high', 
            'type_is_75th Percentile_high','type_is_Bottom 25th Percentile_high']]

y1 = dfinal[['sold_price']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-151-8c71c2d43128> in <module>
#       6 from numpy import std
#       7
# ----> 8 X1 = dfinal[['zipcode','bed', 'bath', 'days_on_market', 'dom_tier', 'dom_lowerbound', 'dom_iqr', 'dom_upperbound','dom_extended',
#       9             'dom_outlier', 'walkable_false', 'walkable_true', 'health_level_dead', 'health_level_fair', 'health_level_good',
#      10             'health_level_poor', 'ada_access_no', 'ada_access_yes', 'ada_access_partial',
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ...

# %%
X1.sample()
# Out:
#        zipcode  bed  bath  days_on_market  dom_tier  dom_lowerbound  dom_iqr  \
# 10550    11368    8 2.000             138         2               0        0
#
#        dom_upperbound  dom_extended  dom_outlier  walkable_false  \
# 10550               1             0            0           0.000
#
#        walkable_true  health_level_dead  health_level_fair  health_level_good  \
# 10550        235.000            222.000            628.000           3296.000
#
#        health_level_poor  ada_access_no  ada_access_yes  ada_access_partial  \
# 10550            200.000          2.000           1.000               0.000
#
#        type_is_active_cleanup_mild_threat  type_is_active_significant_threat  \
# 10550                               1.000                              0.000
#
#        type_is_completed_clean  type_is_maintain_continued_threat  \
# 10550                    2.000                              0.000
#
# ...

# %%
y1.sample()
# Out:
#        sold_price
# 35716      670000

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, random_state = 101)

model = RandomForestRegressor(n_estimators = 900, max_depth = 70, random_state = 101)
model.fit(X1, y1.values.ravel())
# Out:
# RandomForestRegressor(random_state=42)

# %%
y1_pred = model.predict(X_test)
# len(y1_pred), 
X_test
# Out:
#        zipcode  bed  bath  days_on_market  dom_tier  dom_lowerbound  dom_iqr  \
# 25615    11692    2 1.000              32         0               1        0
# 23033    11691   10 5.000             148         2               0        0
# 3102     10453    5 3.500             105         1               0        1
# 24267    11101    2 1.000             154         2               0        0
# 3928     10460    4 3.000              76         1               0        1
# ...        ...  ...   ...             ...       ...             ...      ...
# 23352    11379    1 1.000             364         3               0        0
# 34373    11201    4 3.500             306         3               0        0
# 4408     10456    0 1.000              10         0               1        0
# 16841    11365    2 1.000             105         1               0        1
# 22088    10467    1 1.000             105         1               0        1
#
# ...

# %%
r2 = r2_score(y_test, y1_pred)

print('R-squared scores:', round(r2, 2))
# Out:
# R-squared scores: 0.95

# %%
sorted(zip(model.feature_importances_, X1.columns), reverse=True)
# Out:
# [(0.3294987594788278, 'bath'),
#  (0.24972090813370904, 'zipcode'),
#  (0.07456832200761437, 'days_on_market'),
#  (0.05923159661735102, 'bed'),
#  (0.05876932574827554, 'type_is_completed_clean'),
#  (0.020743799017640292, 'ada_access_yes'),
#  (0.019541409595218155, 'health_level_dead'),
#  (0.013785818930773942, 'health_level_poor'),
#  (0.011249776364503581, 'walkable_true'),
#  (0.011018829537505461, 'type_is_active_cleanup_mild_threat'),
#  (0.007979485449573458, 'dom_iqr'),
#  (0.006731280912040091, 'type_is_misdemeanor'),
#  (0.006286689006762205, 'health_level_good'),
#  (0.005336410356351489, 'health_level_fair'),
#  (0.00488586615740313, 'dom_tier'),
#  (0.004474403644684525, 'danger_level_is_low'),
#  (0.004270646013741504, 'type_is_Top 25th Percentile'),
#  (0.003892491521226356, 'type_is_Top 25th Percentile'),
#  (0.0038535235734980257, 'dom_upperbound'),
#  (0.0038159750626751724, 'lunch_eligibity_high_False'),
#  (0.003567409799758939, 'lunch_eligibity_high_False'),
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
result_regression = X_test
result_regression['sold_price'] = y_test
result_regression['y1_pred'] = y1_pred.tolist()
# result.apply(lambda col: col.drop_duplicates().reset_index(drop=True))
result_regression
# Out:
# <ipython-input-119-8d8e97f2f717>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_regression['sold_price'] = y_test
# <ipython-input-119-8d8e97f2f717>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_regression['y1_pred'] = y1_pred.tolist()
#        zipcode  bed  bath  days_on_market  dom_tier  dom_lowerbound  dom_iqr  \
# 25615    11692    2 1.000              32         0               1        0
# ...

# %%
# Define x axis
x_axis = X_test.zipcode

# Build scatterplot
plt.scatter(x_axis, y_test, c = 'b', alpha = 0.5, marker = 'o', label = 'Real')
plt.scatter(x_axis, y1_pred, c = 'r', alpha = 0.5, marker = 'x', label = 'Predicted')
plt.xlabel('Zip Code')
plt.ylabel('Sale Price')
plt.grid(color = '#D3D3D3', linestyle = 'solid')
plt.legend(loc = 'upper right')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Mean absolute error (MAE)
mae = mean_absolute_error(y_test.values.ravel(), y1_pred)

# Mean squared error (MSE)
mse = mean_squared_error(y_test.values.ravel(), y1_pred)

# Print metrics
print('Mean Absolute Error:', round(mae, 2))
print('Mean Squared Error:', round(mse, 2))
# Out:
# Mean Absolute Error: 78666.01
# Mean Squared Error: 25120646535.19

# %%
# Import GridSearchCV
from sklearn.model_selection import GridSearchCV

# Find the best parameters for the model
parameters = {
    'max_depth': [70, 80, 90, 100],
    'n_estimators': [900, 1000, 1100]
}
gridforest = GridSearchCV(model, parameters, cv = 3, n_jobs = -1, verbose = 1)
gridforest.fit(X_train, y_train)
gridforest.best_params_
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed: 34.0min finished
# C:\Users\bxprd\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# {'max_depth': 70, 'n_estimators': 900}
